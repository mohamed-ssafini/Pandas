# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamed-ssafini/Pandas/blob/main/Longest_taxi_rides.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
filename = 'nyc_taxi_2019-01.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N         151.0         239.0
# 1            2.6         1.0                  N         239.0         246.0
# 2            0.0         1.0                  N         236.0         236.0
# 3            0.0         1.0                  N         193.0         193.0
# 4            0.0         2.0                  N         193.0         193.0
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           1.0          7.0    0.5      0.5        1.65           0.0
# 1           1.0         14.0    0.5      0.5        1.00           0.0
# 2           1.0          4.5    0.5      0.5        0.00           0.0
# 3           2.0          3.5    0.5      0.5        0.00           0.0
# 4           2.0         52.0    0.0      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3          9.95                   NaN
# 1                    0.3         16.30                   NaN
# 2                    0.3          5.80                   NaN
# 3                    0.3          7.55                   NaN
# 4                    0.3         55.55                   NaN

# %%
filename = 'nyc_taxi_2019-01.csv'

df = pd.read_csv(filename,
                usecols=['passenger_count',
                         'trip_distance', 'total_amount'],
                dtype={'total_amount':np.float128})

df.head()
# Out:
#    passenger_count  trip_distance  total_amount
# 0              1.0            1.5          9.95
# 1              1.0            2.6         16.30
# 2              3.0            0.0          5.80
# 3              5.0            0.0          7.55
# 4              5.0            0.0         55.55

# %%
df.sort_values('trip_distance')
# Out:
#          passenger_count  trip_distance  total_amount
# 95818                1.0           0.00        108.30
# 3959536              1.0           0.00          5.30
# 4402563              1.0           0.00        100.30
# 2035072              2.0           0.00         78.35
# 58433                3.0           0.00          3.80
# ...                  ...            ...           ...
# 11081                1.0         128.73        453.44
# 1144878              3.0         142.88        327.38
# 2567394              2.0         144.20         18.80
# 4286612              1.0         700.70          9.00
# 4441815              NaN            NaN           NaN
#
# [4441816 rows x 3 columns]

# %%
df.sort_values('trip_distance', ascending = False)
# Out:
#          passenger_count  trip_distance  total_amount
# 4286612              1.0         700.70          9.00
# 2567394              2.0         144.20         18.80
# 1144878              3.0         142.88        327.38
# 11081                1.0         128.73        453.44
# 56477                1.0         119.80        330.30
# ...                  ...            ...           ...
# 1928911              2.0           0.00          4.30
# 3957601              1.0           0.00         51.30
# 1358316              2.0           0.00         70.26
# 3224263              1.0           0.00          4.30
# 4441815              NaN            NaN           NaN
#
# [4441816 rows x 3 columns]

# %%
df.sort_values('trip_distance', ascending = False)[['trip_distance','total_amount']]
# Out:
#          trip_distance  total_amount
# 4286612         700.70          9.00
# 2567394         144.20         18.80
# 1144878         142.88        327.38
# 11081           128.73        453.44
# 56477           119.80        330.30
# ...                ...           ...
# 1928911           0.00          4.30
# 3957601           0.00         51.30
# 1358316           0.00         70.26
# 3224263           0.00          4.30
# 4441815            NaN           NaN
#
# [4441816 rows x 2 columns]

# %%
df.sort_values('trip_distance', ascending = False)[['trip_distance','total_amount']].iloc[:20]
# Out:
#          trip_distance  total_amount
# 4286612         700.70          9.00
# 2567394         144.20         18.80
# 1144878         142.88        327.38
# 11081           128.73        453.44
# 56477           119.80        330.30
# 1128002         113.71          0.00
# 3842620         110.04        515.82
# 2889394         109.90        375.80
# 1369004         108.50        498.80
# 3449573         107.80        450.30
# 3421004         107.80        501.56
# 3449571         107.80          3.30
# 3449572         107.80          0.30
# 2840976         100.80          9.30
# 2840975         100.80       8001.10
# 3001486          98.38        300.80
# 4223568          91.86        290.00
# 4160600          91.00        467.72
# 1408082          90.91        400.32
# 795552           89.18         63.36

# %%
df.sort_values('trip_distance', kind='mergesort')[['trip_distance','total_amount']].iloc[-20:]
# Out:
#          trip_distance  total_amount
# 1408082          90.91        400.32
# 4160600          91.00        467.72
# 4223568          91.86        290.00
# 3001486          98.38        300.80
# 2840975         100.80       8001.10
# 2840976         100.80          9.30
# 3421004         107.80        501.56
# 3449571         107.80          3.30
# 3449572         107.80          0.30
# 3449573         107.80        450.30
# 1369004         108.50        498.80
# 2889394         109.90        375.80
# 3842620         110.04        515.82
# 1128002         113.71          0.00
# 56477           119.80        330.30
# 11081           128.73        453.44
# 1144878         142.88        327.38
# 2567394         144.20         18.80
# 4286612         700.70          9.00
# 4441815            NaN           NaN

# %%
df.sort_values('trip_distance',
ascending=False)['total_amount'].iloc[:20]
# Out:
# 4286612       9.00
# 2567394      18.80
# 1144878     327.38
# 11081       453.44
# 56477       330.30
# 1128002       0.00
# 3842620     515.82
# 2889394     375.80
# 1369004     498.80
# 3449573     450.30
# 3421004     501.56
# 3449571       3.30
# 3449572       0.30
# 2840976       9.30
# 2840975    8001.10
# 3001486     300.80
# 4223568     290.00
# 4160600     467.72
# 1408082     400.32
# 795552       63.36
# Name: total_amount, dtype: float128

# %%
# Using a descending sort, find the average cost of the 20 longest
# (in distance) taxi rides in January 2019.

df.sort_values('trip_distance',
               ascending=False)['total_amount'].iloc[:20].mean()
# Out:
# 650.87000000000002436

# %%
# Now using an ascending sort, find the average cost of the 20 longest
# (in distance) taxi rides in January 2019.  Specify "mergesort" as the
# sorting algorithm.  Are the results any different?

df.sort_values('trip_distance', kind='mergesort')['total_amount'].iloc[-20:].mean()
# Out:
# 681.7915789473684467

# %%
df.sort_values(['passenger_count', 'trip_distance'],
              ascending=[True, False])
# Out:
#          passenger_count  trip_distance  total_amount
# 3528550              0.0           62.4        320.30
# 3296320              0.0           55.0        336.35
# 1878399              0.0           50.7        227.56
# 4176048              0.0           46.2        200.06
# 2715777              0.0           43.2          0.30
# ...                  ...            ...           ...
# 949907               9.0            0.0         12.60
# 1296224              9.0            0.0          9.30
# 2012030              9.0            0.0         11.30
# 2883943              9.0            0.0         12.25
# 4441815              NaN            NaN           NaN
#
# [4441816 rows x 3 columns]

# %%
df.sort_values(['passenger_count', 'trip_distance'],
              ascending=[True, False])['total_amount']
# Out:
# 3528550    320.30
# 3296320    336.35
# 1878399    227.56
# 4176048    200.06
# 2715777      0.30
#             ...
# 949907      12.60
# 1296224      9.30
# 2012030     11.30
# 2883943     12.25
# 4441815       NaN
# Name: total_amount, Length: 4441816, dtype: float128

# %%
# Sort by ascending passenger count and descending trip distance.  (So we'll start
# with the longest trip with 0 passengers and end with the shortest trip with
# 6 passengers.)  What is the average price paid for the top 50 rides?
df.sort_values(['passenger_count', 'trip_distance'],
              ascending=[True, False])['total_amount'].iloc[:50].mean()
# Out:
# 114.66600000000000116
