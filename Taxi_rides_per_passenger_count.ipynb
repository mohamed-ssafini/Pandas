# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamed-ssafini/Pandas/blob/main/Taxi_rides_per_passenger_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
filename = 'nyc_taxi_2019-01.csv'

df = pd.read_csv(filename,
                usecols=['passenger_count',
                         'trip_distance', 'total_amount'],
               )

df.head()
# Out:
#    passenger_count  trip_distance  total_amount
# 0                1            1.5          9.95
# 1                1            2.6         16.30
# 2                3            0.0          5.80
# 3                5            0.0          7.55
# 4                5            0.0         55.55

# %%
df['passenger_count']
df['passenger_count'].unique()
df['passenger_count'].nunique()
# Out:
# 10

# %%
grouped = df.groupby('passenger_count')
type(grouped)
grouped.ngroups
groups = list(grouped.groups)
groups
grouped.get_group(0.0)
# Out:
#          passenger_count  trip_distance  total_amount
# 156                    0            5.3          4.55
# 228                    0           18.0         59.80
# 229                    0            8.9         38.50
# 298                    0            1.0          9.30
# 905                    0            0.7          8.30
# ...                  ...            ...           ...
# 4489259                0            2.7         15.80
# 4489260                0            0.8          6.35
# 4489261                0            1.4         12.35
# 4489270                0            0.6          5.30
# 4489271                0            1.3           NaN
#
# [67356 rows x 3 columns]

# %%
grouped.get_group(6)
# Out:
#          passenger_count  trip_distance  total_amount
# 176                    6           0.50          5.30
# 178                    6           3.58         24.30
# 204                    6           4.82         20.80
# 401                    6           4.90         28.56
# 471                    6           3.15         16.56
# ...                  ...            ...           ...
# 4488885                6           0.45          5.30
# 4488962                6           1.96         15.36
# 4488963                6           0.68          8.80
# 4488964                6           2.05         15.96
# 4489174                6           0.81          7.25
#
# [118104 rows x 3 columns]

# %%
grouped.head(2)
# Out:
#          passenger_count  trip_distance  total_amount
# 0                      1           1.50          9.95
# 1                      1           2.60         16.30
# 2                      3           0.00          5.80
# 3                      5           0.00          7.55
# 4                      5           0.00         55.55
# 9                      2           2.10         13.00
# 10                     2           2.80         19.55
# 27                     3           0.60          8.15
# 37                     4           1.50          9.30
# 70                     4          18.10         57.80
# 156                    0           5.30          4.55
# 176                    6           0.50          5.30
# 178                    6           3.58         24.30
# 228                    0          18.00         59.80
# 35896                  8           0.01          9.96
# 49225                  8           5.08        109.56
# 183599                 7           4.43         76.06
# 949907                 9           0.00         12.60
# 978273                 7           0.00        -75.80
# 1296224                9           0.00          9.30

# %%
grouped2 = df.groupby('passenger_count')['total_amount']
grouped2.ngroups
grouped2.get_group(6)
# Out:
# 176         5.30
# 178        24.30
# 204        20.80
# 401        28.56
# 471        16.56
#            ...
# 4488885     5.30
# 4488962    15.36
# 4488963     8.80
# 4488964    15.96
# 4489174     7.25
# Name: total_amount, Length: 118104, dtype: float64

# %%
df.groupby('passenger_count')['total_amount'].mean()
# Out:
# passenger_count
# 0    21.209550
# 1    15.663118
# 2    15.956204
# 3    15.839347
# 4    16.011461
# 5    15.597826
# 6    15.545725
# 7    37.729091
# 8    55.957727
# 9    11.362500
# Name: total_amount, dtype: float64

# %%
# For each number of passengers, find the mean cost of a taxi ride.
# Sort this result from lowest (i.e., cheapest) to highest (i.e., most expensive).

df.groupby('passenger_count')['total_amount'].mean().sort_values()
# Out:
# passenger_count
# 9    11.362500
# 6    15.545725
# 5    15.597826
# 1    15.663118
# 3    15.839347
# 2    15.956204
# 4    16.011461
# 0    21.209550
# 7    37.729091
# 8    55.957727
# Name: total_amount, dtype: float64

# %%
# Sort the results once again, in increasing number of passengers.

df.groupby('passenger_count')['total_amount'].mean().sort_index()
# Out:
# passenger_count
# 0    21.209550
# 1    15.663118
# 2    15.956204
# 3    15.839347
# 4    16.011461
# 5    15.597826
# 6    15.545725
# 7    37.729091
# 8    55.957727
# 9    11.362500
# Name: total_amount, dtype: float64

# %%
df['trip_distance_group'] = pd.cut(df['trip_distance'],
                                   [df['trip_distance'].min(), 2, 10,
                                    df['trip_distance'].max()],
                                  labels=['short', 'medium', 'long'], include_lowest=True)
df
# Out:
#          passenger_count  trip_distance  total_amount trip_distance_group
# 0                      1           1.50          9.95               short
# 1                      1           2.60         16.30              medium
# 2                      3           0.00          5.80               short
# 3                      5           0.00          7.55               short
# 4                      5           0.00         55.55               short
# ...                  ...            ...           ...                 ...
# 4489267                1           4.50         27.95              medium
# 4489268                1           3.70         22.55              medium
# 4489269                2          11.64         43.06                long
# 4489270                0           0.60          5.30               short
# 4489271                0           1.30           NaN               short
#
# [4489272 rows x 4 columns]

# %%
df[df['trip_distance'] == 2]
# Out:
#          passenger_count  trip_distance  total_amount trip_distance_group
# 251                    1            2.0         11.15               short
# 261                    2            2.0         10.80               short
# 306                    1            2.0         12.96               short
# 336                    1            2.0         16.64               short
# 463                    1            2.0         10.80               short
# ...                  ...            ...           ...                 ...
# 4488924                1            2.0         17.76               short
# 4489027                1            2.0         15.35               short
# 4489090                1            2.0         12.30               short
# 4489200                1            2.0         15.80               short
# 4489266                1            2.0         11.15               short
#
# [43599 rows x 4 columns]

# %%
df[df['trip_distance'] == 10]
# Out:
#          passenger_count  trip_distance  total_amount trip_distance_group
# 3159                   2           10.0         37.55              medium
# 3743                   1           10.0         31.30              medium
# 15052                  1           10.0         44.55              medium
# 17682                  1           10.0         30.80              medium
# 18192                  1           10.0         31.80              medium
# ...                  ...            ...           ...                 ...
# 4481339                1           10.0         34.30              medium
# 4482494                0           10.0         43.56              medium
# 4483019                2           10.0         41.56              medium
# 4486157                1           10.0         30.80              medium
# 4486239                1           10.0         38.50              medium
#
# [2031 rows x 4 columns]

# %%
df[df['trip_distance'] == 11]
# Out:
#          passenger_count  trip_distance  total_amount trip_distance_group
# 162                    2           11.0         51.63                long
# 10366                  1           11.0         41.15                long
# 11506                  1           11.0         38.80                long
# 11539                  1           11.0         33.30                long
# 18576                  1           11.0         91.80                long
# ...                  ...            ...           ...                 ...
# 4480912                1           11.0         44.15                long
# 4481079                0           11.0         38.75                long
# 4482028                1           11.0         43.55                long
# 4486491                1           11.0         36.30                long
# 4487709                1           11.0         38.75                long
#
# [1513 rows x 4 columns]

# %%
# Now create a new column, `trip_length`, in which the values will be `short`
# (< 2 miles), `medium` (> 2 miles and <= 10 miles), or `long` (> 10 miles).
# What was the average number of passengers per trip length category? Sort
# this result from highest (greatest number of passengers) to lowest
# (smallest number of passengers).

df['trip_distance_group'] = pd.cut(df['trip_distance'],
                                   [df['trip_distance'].min(), 2, 10,
                                    df['trip_distance'].max()],
                                  labels=['short', 'medium', 'long'])
df.groupby('trip_distance_group')['passenger_count'].mean().sort_values(ascending=False)
# Out:
# trip_distance_group
# long      1.603820
# medium    1.590322
# short     1.562011
# Name: passenger_count, dtype: float64
